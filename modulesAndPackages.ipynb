# %% [markdown]
# <a href="https://colab.research.google.com/github/jhuarancca/PythonforDataEngineering/blob/main/modulesAndPackages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %%
# !pip install pandas

# %%
import pandas as pd
data={'name':['Juan de Dios','Oscar','Santos','Luis'],'age':[20,30,40,50]}
df=pd.DataFrame(data)
df
# Out:
#            name  age
# 0  Juan de Dios   20
# 1         Oscar   30
# 2        Santos   40
# 3          Luis   50
